# %% [markdown]
# # Generator

# %%
from generator import dataset_generator
from PIL import Image,ImageDraw
import numpy as np
import random
import matplotlib.pyplot as plt
from matplotlib.image import imread
# %matplotlib inline

# %% [markdown]
# # Generate

# %%
n_rows = 3
n_cols = 3
data = dataset_generator(100)
data_test = data[0]
angles = data[1]
plt.figure(figsize=(17, 17))
for i in range(n_rows*n_cols):
    plt.subplot(n_rows, n_cols, i+1)
    index = random.randint(0, len(data_test)-1)
    image = data_test[index]
    plt.title('angle ' + str("{0:.2f}".format(round(angles[index],2))), fontsize=10)
    plt.tick_params(bottom='off', left='off', labelbottom='off', labelleft='off')
    plt.imshow(image)
